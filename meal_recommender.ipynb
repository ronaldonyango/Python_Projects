# %% [markdown]
# <a href="https://colab.research.google.com/github/ronaldoyw/Python_beginner_projects/blob/main/meal_recommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random 


# Lists
basic_meals = ['Ugali', 'Rice', 'Spaghetti', 'Chapati', 'Chips', 'Githeri', 'Pilau', 'Matoke', 'Maandazi', 'Samosa']
ugali_extra = ['Beef Stew', 'Chicken Stew', 'Deep-fried Chicken', 'Matumbo', 'Minced Meat', 'Eggs', 'Sukuma Wiki', 'Cabbage', 'Terere']
rice_extra = ['Beef Stew', 'Chicken Stew', 'Deep-fried Chicken', 'Minced Meat', 'Eggs', 'Sukuma Wiki', 'Cabbage', 'French Beans', 'Ndengu', 'Kamande', 'Beans', 'Ndengu']
matoke_extra = ['Beef Stew']
chapati_extra = ['Beef Stew', 'Chicken Stew', 'Ndengu', 'Kamande', 'Beans']
meal_drinks = ['Tea', 'Coffee']
toppings = ['Kachumbari', 'Fried Vegetables']
fruits = ['Avocado']
possible_quick_fixes = ['Ugali, Sukuma Wiki & Avocado', 'Rice & Beans', 'Spaghetti', 'Ugali & Cabbage']
not_hungry = ['Spaghetti', 'Rice & Beans']
stew = ['Beef Stew', 'Chicken Stew']
greens = ['Sukuma Wiki', 'Cabbage', 'Terere']
green_veggies = ['French Beans', 'Ndengu', 'Kamande', 'Beans', 'Ndengu']
snacky = ['Maandazi', 'Samosa']
special_occasion_messages = ['Date night? Let\'s go!', 'I love special occasions!!!', 'A special day deserves a special meal', 'You didn\'t tell me it was a special day! I\'m so excited!']
not_hungry_messages = ['Try this light meal', 'Not hungry? Here is a good meal light on your belly', 'Did you know that sometimes you do not need a heavy meal?']
quick_fix_messages = ['It is one of those lazy days right? Worry not, I have got you!', 'After a long day, you deserve an early rest today!', 'Great choice! I have just the perfect meal for you.']
food_choices_messages = ['Did I get it right? Check out more like this above', 'Perfect selection. You will enjoy this one for sure! If you enjoy this one, do not forget to try my suggestions above', 'This one was tailor-made for you! Enjoy your meal. More like this above', 'Be hungry for success! Be hungry for a delicious meal!']
quotes = ['“A lion runs the fastest when he is hungry.” – Salman Khan', '“Everyone wants to eat, but few are willing to hunt.” – Anonymous', '“Be humble. Be hungry. And always be the hardest worker in the room.” – Dwayne Johnson', '“Talent is cheaper than table salt. What separates the talented individual from the successful one is a lot of hard work.” – Stephen King', '“For me life is continuously being hungry. The meaning of life is not simply to exist, to survive, but to move ahead, to go up, to achieve, to conquer.” – Arnold Schwarzenegger', '“Stay hungry and follow your dreams.” – Jack Ma', '“The world is a jungle. You either fight and dominate or hide and evaporate.” – Anonymous', '“If you really want to do something, you will find a way. If you don’t, you’ll find an excuse.” – Jim Rohn', '“When you’re hungry for success, don’t let anyone feed you crap about slowing down.” – Marie Forleo', '“Stay hungry, stay humble” – Tom Brady']
sad_mood = ['Dark chocolate', 'Ice-cream', 'Hot coffee with cookies', 'Lemon tea', 'Green tea', 'Coffee', 'Spicy food', 'Nuts', ' Biryani', ' Chill water', 'Popcorn', 'Milk', 'Milkshare', 'Smoothies']
fear_mood = ['Dark chocolate', 'Orange', 'Eggs', 'Cheese', 'Pineapple', 'Bananas', 'Oats']
anger_mood = ['Fish', 'Chicken', 'Eggs', 'Leafy greens']
happy_mood = ['Dark chocolate', 'Grape', 'Avocado', 'Coconut', 'Coffee', 'Eggs', 'Honey', 'Whole grain bread']
love_mood = ['Dark chocolate', 'Spaghetti', 'Honey', 'Bananas', 'Garlic', 'Ginger', 'Whipped cream']
eat_out = {
    'Pizza': ['Pizza Inn', 'Dominos Pizza', 'Steers', 'Mambo Italia', 'Pizza Mojo', 'La Salumeria'],
    'Hamburger': ['Burger King', 'Urban Burger'],
    'Fried chicken': ['KFC', 'Chicken Inn'],
    'Grilled chicken': ['Galitos'],
    'Coffee': ['Java', 'Cafe Javas'],
    'Italian': ['Mambo Italia', 'Lucca', 'The Talisman Restaurant', 'La Salumeria', 'Urban Eatery', 'Asmara'],
    'Milkshake': ['Creamy Inn', 'Mambo Italia', 'Java', 'CJs', 'Art Caffe'],
    'Date': ['Asmara', 'Java', 'CJs', 'Mambo Italia', 'Art Caffe']
}


# defining functions
def ugali():
    if ugali_choice == 'Beef Stew':
        for i in stew:
            if i == 'Beef Stew':
                continue
            else:
                print("You might be interested in these meals too: ", random_choice.title(), i)
        return (random_choice.title(), ugali_choice, random.choice(fruits))
    elif ugali_choice == 'Chicken Stew':
        for i in stew:
            if i == 'Chicken Stew':
                continue
            else:
                print("You might be interested in these meals too: ", random_choice.title(), i, random.choice(fruits))
        return (random_choice.title(), ugali_choice, random.choice(fruits))
    elif ugali_choice == 'Eggs':
        return (random_choice.title(), ugali_choice, random.choice(fruits))
    elif ugali_choice == 'Sukuma Wiki':
        for i in greens:
            if i == 'Sukuma Wiki':
                continue
            else:
                print("You might be interested in these meals too: ", random_choice.title(), i, random.choice(fruits))
        return random_choice.title(), ugali_choice, random.choice(fruits)
    elif ugali_choice == 'Cabbage':
        for i in greens:
            if i == 'Cabbage':
                continue
            else:
                print("You might be interested in these meals too: ", random_choice.title(), i, random.choice(fruits))
        return random_choice.title(), ugali_choice, random.choice(fruits)
    elif ugali_choice == 'Terere':
        for i in greens:
            if i == 'Terere':
                continue
            else:
                print("You might be interested in these meals too: ", random_choice.title(), i, random.choice(fruits))
        return random_choice.title(), ugali_choice, random.choice(fruits)
    else:
        return (random_choice.title(), ugali_choice)

    
def rice():
    if rice_choice == 'Beef Stew':
        for i in stew:
            if i == 'Beef Stew':
                continue
            else:
                print("You might be interested in these meals too: ")
                print(random_choice.title(), i)
        return (random_choice.title(), rice_choice, random.choice(fruits))
    elif rice_choice == 'Chicken Stew':
        for i in stew:
            if i == 'Chicken Stew':
                continue
            else:
                print("You might be interested in these meals too: ")
                print(random_choice.title(), i, random.choice(fruits))
        return (random_choice.title(), rice_choice, random.choice(fruits))
    elif rice_choice == 'Eggs':
        return (random_choice.title(), rice_choice, random.choice(fruits))
    elif rice_choice == 'Sukuma Wiki':
        for i in greens:
            if i == 'Sukuma Wiki':
                continue
            else:
                print("You might be interested in these meals too: ")
                print(random_choice.title(), i, random.choice(fruits))
        return random_choice.title(), rice_choice, random.choice(fruits)
    elif rice_choice == 'Cabbage':
        for i in greens:
            if i == 'Cabbage':
                continue
            else:
                print("You might be interested in these meals too: ")
                print(random_choice.title(), i, random.choice(fruits))
        return random_choice.title(), rice_choice, random.choice(fruits)
    elif rice_choice == 'Cabbage':
        for i in greens:
            if i == 'Cabbage':
                continue
            else:
                print("You might be interested in these meals too: ")
                print(random_choice.title(), i, random.choice(fruits))
        return random_choice.title(), rice_choice, random.choice(fruits)
    elif rice_choice == 'French Beans':
        for i in greens:
            if i == 'French Beans':
                continue
            else:
                print("You might be interested in these meals too: ")
                print(random_choice.title(), i, random.choice(fruits))
        return random_choice.title(), rice_choice, random.choice(fruits)
    elif rice_choice == 'Beans':
        for i in greens:
            if i == 'Beans':
                continue
            else:
                print("You might be interested in these meals too: ")
                print(random_choice.title(), i, random.choice(fruits))
        return random_choice.title(), rice_choice, random.choice(fruits)
    elif rice_choice == 'Ndengu':
        for i in greens:
            if i == 'Ndengu':
                continue
            else:
                print("You might be interested in these meals too: ")
                print(random_choice.title(), i, random.choice(fruits))
        return random_choice.title(), rice_choice, random.choice(fruits)
    elif rice_choice == 'Kamande':
        for i in greens:
            if i == 'Kamande':
                continue
            else:
                print("You might be interested in these meals too: ")
                print(random_choice.title(), i, random.choice(fruits))
        return random_choice.title(), rice_choice, random.choice(fruits)
    else:
        return (random_choice.title(), rice_choice)

    
def matoke():
    return (random_choice.title(), 'Beef Stew')


def spaghetti():
    return (random_choice.title(), random.choice(fruits))


def githeri():
    return (random_choice.title(), random.choice(fruits))


def chapati():
    return (random_choice.title(),chapati_choice , 'Cabbage', 'Waru')


def chips():
    return (random_choice.title(), random.choice(toppings))


def pilau():
    return (random_choice.title(), random.choice(toppings))


def samosa():
    for i in snacky:
        if i == 'Samosa':
            continue
        else:
            print(i, random.choice(meal_drinks))
    return (op.title(), random.choice(meal_drinks))


def maandazi():
    for i in snacky:
        if i == 'Maandazi':
            continue
        else:
            print(i, random.choice(meal_drinks))
    return (op.title(), random.choice(meal_drinks))


def ugali1():
    if ugali_choice == 'Beef Stew':
        for i in stew:
            if i == 'Beef Stew':
                continue
            else:
                print("You might be interested in these meals too: ", op.title(), i)
        return (op.title(), ugali_choice, random.choice(fruits))
    elif ugali_choice == 'Chicken Stew':
        for i in stew:
            if i == 'Chicken Stew':
                continue
            else:
                print("You might be interested in these meals too: ", op.title(), i, random.choice(fruits))
        return (op.title(), ugali_choice, random.choice(fruits))
    elif ugali_choice == 'Eggs':
        return (op.title(), ugali_choice, random.choice(fruits))
    elif ugali_choice == 'Sukuma Wiki':
        for i in greens:
            if i == 'Sukuma Wiki':
                continue
            else:
                print("You might be interested in these meals too: ", op.title(), i, random.choice(fruits))
        return op.title(), ugali_choice, random.choice(fruits)
    elif ugali_choice == 'Cabbage':
        for i in greens:
            if i == 'Cabbage':
                continue
            else:
                print("You might be interested in these meals too: ", op.title(), i, random.choice(fruits))
        return op.title(), ugali_choice, random.choice(fruits)
    elif ugali_choice == 'Terere':
        for i in greens:
            if i == 'Terere':
                continue
            else:
                print("You might be interested in these meals too: ", op.title(), i, random.choice(fruits))
        return op.title(), ugali_choice, random.choice(fruits)
    else:
        return (op.title(), ugali_choice)

    
def rice1():
    if rice_choice == 'Beef Stew':
        for i in stew:
            if i == 'Beef Stew':
                continue
            else:
                print(op.title(), i)
        print("You wanna try the one above too?")
        return (op.title(), rice_choice, random.choice(fruits))
    elif rice_choice == 'Chicken Stew':
        for i in stew:
            if i == 'Chicken Stew':
                continue
            else:
                print(op.title(), i, random.choice(fruits))
        print("You wanna try the one above too?")
        return (op.title(), rice_choice, random.choice(fruits))
    elif rice_choice == 'Eggs':
        return (op.title(), rice_choice, random.choice(fruits))
    elif rice_choice == 'Sukuma Wiki':
        for i in greens:
            if i == 'Sukuma Wiki':
                continue
            else:
                print(op.title(), i, random.choice(fruits))
        print("You wanna try the one above too?")
        return op.title(), rice_choice, random.choice(fruits)
    elif rice_choice == 'Cabbage':
        for i in greens:
            if i == 'Cabbage':
                continue
            else:
                print(op.title(), i, random.choice(fruits))
        print("You wanna try the one above too?")
        return op.title(), rice_choice, random.choice(fruits)
    elif rice_choice == 'Cabbage':
        for i in greens:
            if i == 'Cabbage':
                continue
            else:
                print(op.title(), i, random.choice(fruits))
        print("You wanna try the one above too?")
        return op.title(), rice_choice, random.choice(fruits)
    elif rice_choice == 'French Beans':
        for i in green_veggies:
            if i == 'French Beans':
                continue
            else:
                print(op.title(), i, random.choice(fruits))
        print("You wanna try the one above too?")
        return op.title(), rice_choice, random.choice(fruits)
    elif rice_choice == 'Beans':
        for i in green_veggies:
            if i == 'Beans':
                continue
            else:
                print(op.title(), i, random.choice(fruits))
        print("You wanna try the one above too?")
        return op.title(), rice_choice, random.choice(fruits)
    elif rice_choice == 'Ndengu':
        for i in green_veggies:
            if i == 'Ndengu':
                continue
            else:
                print(op.title(), i, random.choice(fruits))
        print("You wanna try the one above too?")
        return op.title(), rice_choice, random.choice(fruits)
    elif rice_choice == 'Kamande':
        for i in green_veggies:
            if i == 'Kamande':
                continue
            else:
                print(op.title(), i, random.choice(fruits))
        print("You wanna try the one above too?")
        return op.title(), rice_choice, random.choice(fruits)
    else:
        return (op.title(), rice_choice)

    
def matoke1():
    return (op.title(), 'Beef Stew')


def spaghetti1():
    return (op.title(), random.choice(fruits))


def githeri1():
    return (op.title(), random.choice(fruits))


def chapati1():
    return (op.title(),chapati_choice , 'Cabbage', 'Waru')


def chips1():
    return (op.title(), random.choice(toppings))


def pilau1():
    return (op.title(), random.choice(toppings))


def samosa1():
    for i in snacky:
        if i == 'Samosa':
            continue
        else:
            print(i, random.choice(meal_drinks))
    print("You wanna try the one above too?")
    return (op.title(), random.choice(meal_drinks))


def maandazi1():
    for i in snacky:
        if i == 'Maandazi':
            continue
        else:
            print(i, random.choice(meal_drinks))
    print("You wanna try the one above too?")
    return (op.title(), random.choice(meal_drinks))


# takes user name
name = input("Hello, welcome to my meal recommender. To get started, please tell me your name: \n")
print(random.choice(quotes))


# user chooses what type of recommendation they want
occasion = int(input("""
Hey, {}. Are you ready to make the best Food meant for you? Let's get started buddy. 

(Choose a number)
1. Special occasion dish
2. I'm not that hungry
3. I'm feeling lazy today. I need a quick fix dish
4. I don't know what I want to eat
5. Feeling moody?
6. Eat out suggestions?
7. I have a slight idea of a dish
""".format(name.title())))


while occasion < 8:
    if occasion == 1:
        print(random.choice(special_occasion_messages))
        print("""
    Bon apetit!
    1. Pilau, Kachumbari, Juice
    2. Pilau, Fried veggies, Juice
    3. Rice, Beef stew, Juice
        """)
        break
    # recommendation for not hungry user
    elif occasion == 2:
        print(random.choice(not_hungry_messages), "\n")
        print(random.choice(not_hungry))
        break
    # quick fix recommendation
    elif occasion == 3:
        print(random.choice(quick_fix_messages), "\n")
        print(random.choice(possible_quick_fixes))
        break
    # random meal recommendation. No user input
    elif occasion == 4:
        random_choice = random.choice(basic_meals).lower()
        if random_choice == 'ugali':
            print(random.choice(food_choices_messages), "\n")
            print(ugali())
            break
        elif random_choice == 'rice':
            rice_choice = random.choice(rice_extra)
            print(random.choice(food_choices_messages), "\n")
            print(rice())
            break
        elif random_choice == 'matoke':
            print(random.choice(food_choices_messages), "\n")
            print(matoke())
            break
        elif random_choice == 'spaghetti':
            print(random.choice(food_choices_messages), "\n")
            print(spaghetti())
            break
        elif random_choice == 'githeri':
            print(random.choice(food_choices_messages), "\n")
            print(githeri())
            break
        elif random_choice == 'chapati':
            chapati_choice = random.choice(chapati_extra)
            print(random.choice(food_choices_messages), "\n")
            print(chapati())
            break
        elif random_choice == 'chips':
            print(random.choice(food_choices_messages), "\n")
            print(chips())
            break
        elif random_choice == 'pilau':
            print(random.choice(food_choices_messages), "\n")
            print(pilau())
        elif random_choice == 'samosa':
            print(random.choice(food_choices_messages), "\n")
            print(samosa())
            break
        elif random_choice == 'maandazi':
            print(random.choice(food_choices_messages), "\n")
            print(maandazi())
            break
        else:
            print("Check your spelling or enter one of the Basic choices above")
            break
    # recommendations according to moods
    elif occasion == 5:
        mood = input("How are you feeling today?\n").lower()
        if mood == 'sad':
            print("I'm sorry about how you feel today, this should make you feel better;", random.choice(sad_mood))
            break
        elif mood == 'depressed':
            print("You are not alone.", random.choice(sad_mood), "will lift your spirits.")
            break
        elif mood == 'fear':
            print("Do the thing you FEAR to do and keep on DOING IT... That is the quickest and surest WAY to ver yet discoured to CONQUER FEAR. Take", random.choice(fear_mood), "and let's COUNQUER that FEAR!!")
            break
        elif mood == 'angry':
            print("If you are patient in one moment of anger, you escape a hundred days of sorrow", random.choice(anger_mood), "brings out the calmness in you.")
            break
        elif mood == 'happy':
            print("Be healthy and take care of yourself, but be happy with the beautiful things that make you, you. In the mood for", random.choice(anger_mood), "today?")
            break
        elif mood == 'heartbreak':
            print("Hearts will never be practical until they are made unbreakable. Heal with", random.choice(sad_mood))
            break
        elif mood == 'stress':
            print("The greatest weapon against stress is our ability to choose one thought over another. Choose", random.choice(sad_mood), "over stress")
            break
        elif mood == 'love':
            print(random.choice(love_mood), ". I love you begins by I, but it ends up by you.")
            break
        elif mood == 'romantic':
            print(random.choice(love_mood), ". I love you begins by I, but it ends up by you.")
            break
        else:
            occasion = int(input("""
Hey, {}. Are you ready to make the best Food meant for you? Let's get started buddy. 

(Choose a number)
1. Special occasion dish
2. I'm not that hungry
3. I'm feeling lazy today. I need a quick fix dish
4. I don't know what I want to eat
5. Feeling moody?
6. Eat out suggestions?
7. I have a slight idea of a dish
""".format(name.title())))
    # eat out recommendations with Restaurant recommendations     
    elif occasion == 6:
        eatout_food = input("Perfect day for an eat out. Mmmh what do you have in mind?: \n").title()
        if eatout_food == 'Pizza':
          print("Here are some cool places! ", eat_out['Pizza'])
          break
        elif eatout_food == 'Hamburger':
          print("Here are some cool places! ", eat_out['Hamburger'])
          break
        elif eatout_food == 'Fried chicken':
          print("Here are some cool places! ", eat_out['Fried chicken'])
          break
        elif eatout_food == 'Grilled chicken':
          print("Here are some cool places! ", eat_out['Grilled chicken'])
          break
        elif eatout_food == 'Coffee':
          print("Here are some cool places! ", eat_out['Coffee'])
          break
        elif eatout_food == 'Italian':
          print("Here are some cool places! ", eat_out['Italian'])
          break
        elif eatout_food == 'Milkshake':
          print("Here are some cool places! ", eat_out['Milkshake'])
          break
        elif eatout_food == 'Date':
          print("Here are some cool places! ", eat_out['Date'])
          break
        else:
          occasion = int(input("""
Hey, {}. Are you ready to make the best Food meant for you? Let's get started buddy. 

(Choose a number)
1. Special occasion dish
2. I'm not that hungry
3. I'm feeling lazy today. I need a quick fix dish
4. I don't know what I want to eat
5. Feeling moody?
6. Eat out suggestions?
7. I have a slight idea of a dish
""".format(name.title())))
    # if user at least has an idea, they can get a recommendation based on the idea
    else:
        op = input("What are we cooking today?\n").lower()
        if op == 'ugali':
            ugali_choice = random.choice(ugali_extra)
            print(random.choice(food_choices_messages), "\n")
            print(ugali1())   
        elif op == 'rice':
            rice_choice = random.choice(rice_extra)
            print(random.choice(food_choices_messages), "\n")
            print(rice1())
        elif op == 'matoke':
            print(random.choice(food_choices_messages), "\n")
            print(matoke1())
        elif op == 'spaghetti':
            print(random.choice(food_choices_messages), "\n")
            print(spaghetti1())
        elif op == 'githeri':
            print(random.choice(food_choices_messages), "\n")
            print(githeri1())
        elif op == 'chapati':
            print(random.choice(food_choices_messages), "\n")
            chapati_choice = random.choice(chapati_extra)
            print(chapati1())
        elif op == 'chips':
            print(random.choice(food_choices_messages), "\n")
            print(chips1())
        elif op == 'pilau':
            print(random.choice(food_choices_messages), "\n")
            print(pilau1())
        elif op == 'samosa':
            print(random.choice(food_choices_messages), "\n")
            print(samosa1())
        elif op == 'maandazi':
            print(random.choice(food_choices_messages), "\n")
            print(maandazi1())
        else:
            print("Check your spelling or enter one of the Basic choices above")

        selection = int(input("""
    Do you want to choose a different meal?
    1. YES
    0. NO"""))
        if selection == 1:
            occasion = int(input("""
Hey, {}. Are you ready to make the best Food meant for you? Let's get started buddy. 

(Choose a number)
1. Special occasion dish
2. I'm not that hungry
3. I'm feeling lazy today. I need a quick fix dish
4. I don't know what I want to eat
5. Feeling moody?
6. Eat out suggestions?
7. I have a slight idea of a dish
""".format(name.title())))
        elif selection == 0:
            print(f"ENJOY YOUR MEAL, {name.upper()}!")
            break
# Out:
# Hello, welcome to my meal recommender. To get started, please tell me your name:
# ronalds
# “The world is a jungle. You either fight and dominate or hide and evaporate.” – Anonymous
#
# Hey, Ronalds. Are you ready to make the best Food meant for you? Let's get started buddy.
#
# (Choose a number)
# 1. Special occasion dish
# 2. I'm not that hungry
# 3. I'm feeling lazy today. I need a quick fix dish
# 4. I don't know what I want to eat
# 5. Feeling moody?
# 6. Eat out suggestions?
# 7. I have a slight idea of a dish
# 7
# Enter meal of choicerice
# This one was tailor-made for you! Enjoy your meal. More like this above
#
# ('Rice', 'Minced Meat')
#
#     Do you want to choose a different meal?
#     1. YES
#     0. NO1
#
# Hey, Ronalds. Are you ready to make the best Food meant for you? Let's get started buddy.
#
# (Choose a number)
# 1. Special occasion dish
# 2. I'm not that hungry
# 3. I'm feeling lazy today. I need a quick fix dish
# 4. I don't know what I want to eat
# ...
